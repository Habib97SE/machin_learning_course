# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("./data/Advertising.csv", index_col=0)

df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 1 to 200
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 7.8 KB

# %%
df.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
df.describe().T
# Out:
#            count      mean        std  min     25%     50%      75%    max
# TV         200.0  147.0425  85.854236  0.7  74.375  149.75  218.825  296.4
# Radio      200.0   23.2640  14.846809  0.0   9.975   22.90   36.525   49.6
# Newspaper  200.0   30.5540  21.778621  0.3  12.750   25.75   45.100  114.0
# Sales      200.0   14.0225   5.217457  1.6  10.375   12.90   17.400   27.0

# %%
df.shape # 200 samples, 3 features, 1 label
# Out:
# (200, 4)

# %%
number_features = df.shape[1] - 1
number_features
# Out:
# 3

# %%
fig, ax = plt.subplots(1, number_features, figsize = (16, 4), dpi= 150)

for i, feature in enumerate(df.columns[:-1]):
    sns.scatterplot(data=df, x=feature, y="Sales", ax=ax[i])

# %%
ax = sns.pairplot(df, height=2)

# %%
X, y = df["TV"], df["Sales"]

X, y
# Out:
# (1      230.1
#  2       44.5
#  3       17.2
#  4      151.5
#  5      180.8
#         ...
#  196     38.2
#  197     94.2
#  198    177.0
#  199    283.6
#  200    232.1
#  Name: TV, Length: 200, dtype: float64,
#  1      22.1
#  2      10.4
#  3       9.3
#  4      18.5
#  5      12.9
#         ...
#  196     7.6
#  197     9.7
#  198    12.8
#  199    25.5
#  200    13.4
#  Name: Sales, Length: 200, dtype: float64)

# %%
beta_1, beta_0 = np.polyfit(X, y, deg = 1)

# %%
y_hat = lambda x: beta_0 + beta_1 * x 

spending= np.linspace(0, 350)

ax = sns.scatterplot(data=df, x="TV", y="Sales" )
sns.lineplot(x = spending, y=y_hat(spending), color="red")

ax.set(title= "Regresson line on TV and Sale")
# Out:
# [Text(0.5, 1.0, 'Regresson line on TV and Sale')]

# %%
sns.regplot(x=X, y=y)
# Out:
# <AxesSubplot: xlabel='TV', ylabel='Sales'>

# %% [markdown]
# ## Multiple linear regression

# %%
X, y = df.drop("Sales", axis="columns"), df["Sales"]

X.head()
# Out:
#       TV  Radio  Newspaper
# 1  230.1   37.8       69.2
# 2   44.5   39.3       45.1
# 3   17.2   45.9       69.3
# 4  151.5   41.3       58.5
# 5  180.8   10.8       58.4

# %%
y.head()
# Out:
# 1    22.1
# 2    10.4
# 3     9.3
# 4    18.5
# 5    12.9
# Name: Sales, dtype: float64

# %%
X.insert(0, "Intercept", 1)

# %%
regression_fit = lambda X, y: np.linalg.inv(X.T@X) @ X.T @ y

beta_hat = regression_fit(X, y)

beta_hat
# Out:
# 0    2.938889
# 1    0.045765
# 2    0.188530
# 3   -0.001037
# dtype: float64

# %%
predict = lambda x, beta: np.dot(x, beta)

test_sample = [1, 230, 38, 69]

y_hat = predict(test_sample, beta_hat)

print(f"With $230k on TV, $38k on Radio and $69k on newspaper we get a predicted sales on ${y_hat:.1f}k")
# Out:
# With $230k on TV, $38k on Radio and $69k on newspaper we get a predicted sales on $20.6k

# %% [markdown]
# ## Train|test split

# %%
train_fraction = int(len(df) * 0.7)

train = df.sample(n=train_fraction, random_state=42, replace=False)
train.head()
# Out:
#         TV  Radio  Newspaper  Sales
# 96   163.3   31.6       52.9   16.9
# 16   195.4   47.7       52.9   22.4
# 31   292.9   28.3       43.2   21.4
# 159   11.7   36.9       45.2    7.3
# 129  220.3   49.0        3.2   24.7

# %%
test = df.drop(train.index)
train.shape, test.shape
# Out:
# ((140, 4), (60, 4))

# %%
X_train, y_train = train.drop("Sales", axis="columns"), train["Sales"]
X_test, y_test = test.drop("Sales", axis="columns"), test["Sales"]

X_train.insert(0, "Intercept", 1)
X_test.insert(0, "Intercept", 1)

X_train.shape, y_train.shape, X_test.shape, y_train.shape
# Out:
# ((140, 4), (140,), (60, 4), (140,))

# %%
beta_hat = regression_fit(X_train, y_train)
print(f"Beta parameters:\n{beta_hat}")
# Out:
# Beta parameters:
# 0    2.956094
# 1    0.046793
# 2    0.187063
# 3   -0.004805
# dtype: float64

# %% [markdown]
# ## Prediction

# %%
beta_hat = regression_fit(X_train, y_train)
print(f"Beta parameters:\n{beta_hat}")


def predict(X, weights): return X @ weights


beta_hat = np.reshape(beta_hat.to_numpy(), (4, 1))

y_hat = predict(X_test, beta_hat).to_numpy()

y_hat[:5]
# Out:
# Beta parameters:
# 0    2.956094
# 1    0.046793
# 2    0.187063
# 3   -0.004805
# dtype: float64
# array([[12.17324122],
#        [12.19125728],
#        [ 3.74653773],
#        [ 8.90545078],
#        [18.43980126]])

# %%
X_test.iloc[1]

# spending 120.2k on TV, 19.6k on radio and 11.6k on newspaper gives prediciton on 12.19k units.
# Out:
# Intercept      1.0
# TV           120.2
# Radio         19.6
# Newspaper     11.6
# Name: 8, dtype: float64

# %% [markdown]
# ## Evaluate model performance

# %%
m = len(y_test)

# removed extra dimension (60,1) -> (60,)
y_hat = np.reshape(y_hat, (m))

mean_absolute_error = 1/m*np.sum(np.abs(y_test-y_hat))
mean_squared_error = 1/m*np.sum((y_test-y_hat)**2)
root_mean_squared_error = np.sqrt(mean_squared_error)

mean_absolute_error, mean_squared_error, root_mean_squared_error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[123], line 4
#       1 m = len(y_test)
#       3 # removed extra dimension (60,1) -> (60,)
# ----> 4 y_hat = np.reshape(y_hat, (m))
#       6 mean_absolute_error = 1/m*np.sum(np.abs(y_test-y_hat))
#       7 mean_squared_error = 1/m*np.sum((y_test-y_hat)**2)
#
# File <__array_function__ internals>:200, in reshape(*args, **kwargs)
#
# File c:\Users\hheza\.virtualenvs\tutorial-1KPwQ9s2\Lib\site-packages\numpy\core\fromnumeric.py:298, in reshape(a, newshape, order)
#     198 @array_function_dispatch(_reshape_dispatcher)
#     199 def reshape(a, newshape, order='C'):
#     200     """
#     201     Gives a new shape to an array without changing its data.
#     202
#    (...)
#     296            [5, 6]])
#     297     """
# --> 298     return _wrapfunc(a, 'reshape', newshape, order=order)
#
# File c:\Users\hheza\.virtualenvs\tutorial-1KPwQ9s2\Lib\site-packages\numpy\core\fromnumeric.py:54, in _wrapfunc(obj, method, *args, **kwds)
#      52 bound = getattr(obj, method, None)
#      53 if bound is None:
# ---> 54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
#      57     return bound(*args, **kwds)
#
# File c:\Users\hheza\.virtualenvs\tutorial-1KPwQ9s2\Lib\site-packages\numpy\core\fromnumeric.py:43, in _wrapit(obj, method, *args, **kwds)
#      41 except AttributeError:
#      42     wrap = None
# ---> 43 result = getattr(asarray(obj), method)(*args, **kwds)
#      44 if wrap:
#      45     if not isinstance(result, mu.ndarray):
#
# ValueError: cannot reshape array of size 1 into shape (60,)
